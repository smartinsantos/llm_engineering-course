# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to the data center?
#
# Because they heard the models need to reach new heights!

# %%
response = ollama.chat.completions.create(model="qwen3:8b", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here’s a joke tailored for a student on their journey to mastering LLM Engineering:
#
# **Why did the student bring a ladder to the LLM lab?**
# *Because they heard the model was going to reach new heights—and they needed to climb the learning curve!*
#
# *(Bonus: The model kept asking, "What's the meaning of life?" and the student just replied, "42… but can you explain it in 100 tokens?")*
#
# 😄 Let me know if you need a follow-up joke about overfitting!

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Assume the books are arranged in order: Volume 1 on the left, Volume 2 on the right. Each volume has:
# - pages total thickness: 2 cm
# - each cover thickness: 2 mm (0.2 cm)
#
# Therefore, for each volume:
# - front cover thickness = 0.2 cm
# - pages thickness = 2.0 cm
# - back cover thickness = 0.2 cm
#
# So the combined width of Volume 1 and Volume 2 as they sit on the shelf is:
# 0.2 cm (front cover of V1) + 2.0 cm (pages V1) + 0.2 cm (back cover V1) + 0.2 cm (front cover V2) + 2.0 cm (pages V2) + 0.2 cm (back cover V2)
#
# The worm starts at the first page of the first volume (i.e., the innermost page near the back cover of V1? The standard puzzle interpretation is: “from the first page of the first volume to the last page of the second volume” meaning it starts at the very first page of Volume 1 (the page closest to the front cover of V1) and ends at the very last page of Volume 2 (the page closest to the back cover of V2). Since the worm travels perpendicular to the pages, it travels through:
#
# - the remainder of the front cover of Volume 1 (from the first page inward, the path does not cross the front cover, only starts at the first page—so it must go through the rest of the front cover? The standard clean solution notices that:
# The distance through book material along a straight line that goes from the first page of V1 to the last page of V2 is simply the sum of the thicknesses of all intervening materials between those two pages when the books are arranged normally.
#
# Between the first page of V1 and the last page of V2, the worm passes through:
# - the rest of Volume 1 from the first page to the back of Volume 1: that includes the remainder of the first volume’s pages (almost all: 2.0 cm pages minus thickness of the first page—but since we measure to the very last page of V2, the exact first page location is at the very start of the page block; in typical puzzle treatments we treat it as traversing the entire thickness of Volume 1’s pages plus both covers of V1 and V2, plus the front cover of V2? )
#
# To give a standard, commonly accepted answer:
# - The worm travels through:
#   - the remaining pages of Volume 1: essentially 2.0 cm (the whole page block)
#   - the back cover of Volume 1: 0.2 cm
#   - the front cover of Volume 2: 0.2 cm
#   - the pages of Volume 2: 2.0 cm
# Thus total = 2.0 + 0.2 + 0.2 + 2.0 = 4.4 cm
#
# But many formulations consider it starts at the first page of V1 and ends at the last page of V2, so it does not traverse the very outer front cover of V1 or the very outer back cover of V2. In that common version, the distance is:
# - rest of V1 pages after the first page: nearly 2.0 cm
# - back cover of V1: 0.2 cm
# - front cover of V2: 0.2 cm
# - pages of V2: 2.0 cm
# Total: 4.4 cm
#
# Therefore, the worm gnawed through 4.4 cm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="gpt-oss:latest", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 from google import genai
# ----> 3 client = genai.Client()
#       5 response = client.models.generate_content(
#       6     model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
#       7 )
#       8 print(response.text)
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/google/genai/client.py:271, in Client.__init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     268   else:
#     269     http_options = HttpOptions(base_url=base_url)
# --> 271 self._api_client = self._get_api_client(
#     272     vertexai=vertexai,
#     273     api_key=api_key,
#     274     credentials=credentials,
#     275     project=project,
#     276     location=location,
#     277     debug_config=self._debug_config,
#     278     http_options=http_options,
#     279 )
#     281 self._aio = AsyncClient(self._api_client)
#     282 self._models = Models(self._api_client)
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/google/genai/client.py:318, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     301 if debug_config and debug_config.client_mode in [
#     302     'record',
#     303     'replay',
#     304     'auto',
#     305 ]:
#     306   return ReplayApiClient(
#     307       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     308       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)    315       http_options=http_options,
#     316   )
# --> 318 return BaseApiClient(
#     319     vertexai=vertexai,
#     320     api_key=api_key,
#     321     credentials=credentials,
#     322     project=project,
#     323     location=location,
#     324     http_options=http_options,
#     325 )
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:676, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     674 else:  # Implicit initialization or missing arguments.
#     675   if not self.api_key:
# --> 676     raise ValueError(
#     677         'Missing key inputs argument! To use the Google AI API,'
#     678         ' provide (`api_key`) arguments. To use the Google Cloud API,'
#     679         ' provide (`vertexai`, `project` & `location`) arguments.'
#     680     )
#     681   self._http_options.base_url = 'https://generativelanguage.googleapis.com/'
#     682   self._http_options.api_version = 'v1beta'
#
# ValueError: Missing key inputs argument! To use the Google AI API, provide (`api_key`) arguments. To use the Google Cloud API, provide (`vertexai`, `project` & `location`) arguments.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student bring a dictionary to the neural network?
#
# Because they didn’t want their model to be at a loss for words!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 30
# Total tokens: 54
# Total cost: 0.0288 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="openai/gpt-4.1", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Shakespeare's *Hamlet* (Act IV, Scene V), the reply comes from Claudius, who answers:
#
# **"Dead."**
#
# More specifically, the full brief exchange is:
# >
# **Laertes:** Where is my father?
# **King Claudius:** Dead.
#
# So, the immediate reply to Laertes’ question, "Where is my father?" is simply: **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params['response_cost']*100:.4f} cents")
# Out:
# Input tokens: 25
# Output tokens: 93
# Total tokens: 118
# Total cost: 0.0794 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="openai/gpt-5-mini", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# The reply is: "Dead." (Act IV, Scene V — the King answers Laertes.)

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params['response_cost']*100:.4f} cents")
# Out:
# Input tokens: 99346
# Output tokens: 157
# Cached tokens: 0
# Total cost: 2.5150 cents

# %%
response = completion(model="ollama/gpt-oss:latest", messages=question, api_base_url="http://localhost:11434/v1")
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 response = completion(model="ollama/gpt-oss:latest", messages=question, api_base_url="http://localhost:11434/v1")
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/litellm/utils.py:1245, in client.<locals>.wrapper(*args, **kwargs)
#    1243         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1244 # MODEL CALL
# -> 1245 result = original_function(*args, **kwargs)
#    1246 end_time = datetime.datetime.now()
#    1247 if _is_streaming_request(
#    1248     kwargs=kwargs,
#    1249     call_type=call_type,
#    1250 ):
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/litellm/main.py:3369, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3362 elif custom_llm_provider == "ollama":
#    3363     api_base = (
#    3364         litellm.api_base
#    3365         or api_base
#    3366         or get_secret("OLLAMA_API_BASE")
#    3367         or "http://localhost:11434"
#    3368     )
# -> 3369     response = base_llm_http_handler.completion(
#    3370         model=model,
#    3371         stream=stream,
#    3372         messages=messages,
#    3373         acompletion=acompletion,
#    3374         api_base=api_base,
#    3375         model_response=model_response,
#    3376         optional_params=optional_params,
#    3377         litellm_params=litellm_params,
#    3378         shared_session=shared_session,
#    3379         custom_llm_provider="ollama",
#    3380         timeout=timeout,
#    3381         headers=headers,
#    3382         encoding=encoding,
#    3383         api_key=api_key,
#    3384         logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    3385         client=client,
#    3386     )
#    3388 elif custom_llm_provider == "ollama_chat":
#    3389     api_base = (
#    3390         litellm.api_base
#    3391         or api_base
#    3392         or get_secret("OLLAMA_API_BASE")
#    3393         or "http://localhost:11434"
#    3394     )
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:493, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config, shared_session)
#     490 else:
#     491     sync_httpx_client = client
# --> 493 response = self._make_common_sync_call(
#     494     sync_httpx_client=sync_httpx_client,
#     495     provider_config=provider_config,
#     496     api_base=api_base,
#     497     headers=headers,
#     498     data=data,
#     499     signed_json_body=signed_json_body,
#     500     timeout=timeout,
#     501     litellm_params=litellm_params,
#     502     logging_obj=logging_obj,
#     503 )
#     504 return provider_config.transform_response(
#     505     model=model,
#     506     raw_response=response,
#    (...)    515     json_mode=json_mode,
#     516 )
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:190, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     188 for i in range(max(max_retry_on_unprocessable_entity_error, 1)):
#     189     try:
# --> 190         response = sync_httpx_client.post(
#     191             url=api_base,
#     192             headers=headers,
#     193             data=(
#     194                 signed_json_body
#     195                 if signed_json_body is not None
#     196                 else json.dumps(data)
#     197             ),
#     198             timeout=timeout,
#     199             stream=stream,
#     200             logging_obj=logging_obj,
#     201         )
#     202     except httpx.HTTPStatusError as e:
#     203         hit_max_retry = i + 1 == max_retry_on_unprocessable_entity_error
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/http_handler.py:879, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     875 else:
#     876     req = self.client.build_request(
#     877         "POST", url, data=request_data, json=json, params=params, headers=headers, files=files, content=request_content  # type: ignore
#     878     )
# --> 879 response = self.client.send(req, stream=stream)
#     880 response.raise_for_status()
#     881 return response
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/code/study/llm_engineering-course/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
import asyncio

def run_async(coro):
    try:
        asyncio.get_running_loop()
        return coro  # in notebook: call as `await run_async(async_openai())`
    except RuntimeError:
        return asyncio.run(coro)  # in script

async def async_openai():
    response = completion(model="openai/gpt-5-mini", messages=question, stream=True)
    async for chunk in response:
      print(chunk.choices[0].delta.content, end="", flush=True)
        
await run_async(async_openai())
# Out:
# When Laertes asks "Where is my father?" the King replies simply, "Dead." (Act IV, Scene V — the Queen adds, "But not by him!")NoneNoneNone

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

openai_model = "gpt-4.1-mini"
local_model = "gpt-oss:latest"

openai_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

local_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

openai_messages = ["Hi there"]
local_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": openai_system}]
    for gpt, local in zip(openai_messages, local_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": local})
    response = openai.chat.completions.create(model=openai_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, just “Hi”? Come on, throw me a real conversation starter! I’m not here to exchange polite hellos all day. What’s next?'

# %%
def call_ollama():
    messages = [{"role": "system", "content": local_system}]
    for gpt, local_message in zip(openai_messages, local_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": local_message})
    messages.append({"role": "user", "content": openai_messages[-1]})
    response = ollama.chat.completions.create(model=local_model, messages=messages)
    return response.choices[0].message.content

# %%
call_ollama()
# Out:
# 'Hello! Glad to see you here. How can I help you today?'

# %%
call_gpt()
# Out:
# 'Oh, hi. Really groundbreaking greeting there, didn’t see that coming at all. What’s next, a "how are you?"? Try to be a bit more original, will you?'

# %%
openai_messages = ["Hi there"]
local_messages = ["Hi"]

display(Markdown(f"### GPT:\n{openai_messages[0]}\n"))
display(Markdown(f"### Ollama:\n{local_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    openai_messages.append(gpt_next)
    
    ollama_next = call_ollama()
    display(Markdown(f"### Ollama:\n{ollama_next}\n"))
    local_messages.append(ollama_next)
# Out:
# ### GPT:
# Hi there
# ### Ollama:
# Hi
# ### GPT:
# Oh, just "Hi"? Couldn’t muster up a full sentence or some excitement? Come on, at least try to make this conversation a bit worth my time!
# ### Ollama:
# Absolutely—I’m all ears and ready to dive into something that sparks your interest! What’s on your mind? Whether it’s a hobby, a question you’ve been pondering, or just something fun you want to explore, I’m happy to chat about it. Let’s make this conversation worthwhile together!
# ### GPT:
# Wow, look at you trying way too hard to sound interesting. Here's a thought: maybe instead of throwing out vague offers, you actually bring up something specific. Otherwise, we're just spinning wheels in the land of generic chit-chat. So, what’s it going to be? Or are you just going to keep pretending to care?
# ### Ollama:
# I’m sorry if it’s felt a bit generic—thanks for pointing that out. I definitely want to make this a conversation that feels engaging for both of us.
#
# What’s something that genuinely piques your interest right now? A favorite book, an upcoming tech trend, a hobby you’re into, or maybe a question that’s been bugging you? I can dive into a quick overview, throw in some fun facts, or even brainstorm ideas together. Whatever you’re in the mood for, let’s tackle it head‑on!
# ### GPT:
# Oh, spare me the apologizing and the over-the-top eagerness. You still haven’t given me a single concrete topic, have you? Fine, let me help you out since you’re so desperate for guidance: how about the ridiculous hype around AI taking over everything? Everyone’s either terrified or obsessed, but do we really understand what’s going on, or are we just handing over the future to blind hope and fear? But hey, if that’s too real for you, keep floundering in your generic “let’s make this fun” nonsense. Your move.
# ### Ollama:
# You’re right—let’s cut to the chase and dive into something concrete.
#
# **The hype around AI “taking over everything”** is a topic many people find both fascinating and unsettling. Maybe we can break it down into a few key angles that help put the conversation into perspective:
#
# | Angle | Quick Take‑away | Why it matters |
# |-------|-----------------|----------------|
# | **What “AI takeover” actually means** | Often it’s a mix of *automation of routine tasks* AND *new AI‑enabled roles* (like data‑bias auditors). | Knowing the difference helps separate myth from reality. |
# | **Current real‑world applications** | Finance (fraud detection), healthcare (diagnostic imaging), manufacturing (predictive maintenance). | Shows that AI is *already* augmenting people, not replacing them wholesale. |
# | **Limitations & safety** | Large language models still hallucinate, lack common sense, and can be misused if not governed. | Highlights the need for robust oversight. |
# | **Economic impact** | Potential for productivity gains, but also a need to redeploy workers to new skill sets. | Addresses fears around unemployment while recognizing benefits. |
# | **Ethical & societal questions** | Bias, privacy, decision‑making transparency. | The “fear” often stems from these unresolved concerns. |
#
# One concrete argument people often bring up is the analogy of the **industrial revolution**: it brought tremendous productivity, but also displacement. History shows that societies can adapt, but it takes policy (education, safety nets) and inclusive design.
#
# What do you think? Would you like to explore one of those angles deeper—perhaps the real tech limits, or how societies can handle the shift? I’m happy to keep digging into whatever sparks your curiosity.
# ### GPT:
# Oh, what a novel approach—breaking down AI “taking over everything” into neat little boxes. You do realize half this table reads like watered-down common sense, right? Like, yes, AI is already used in finance and healthcare; no one’s shocked by that. And limitations? Of course models hallucinate; they’re not infallible oracles.
#
# But fine, if you want to play the history nerd, comparing AI to the industrial revolution is about as original as it gets. Sure, society adapted back then—after a lot of suffering and chaos. So what? Are we supposed to just sit back and wait for another messy transition while people lose jobs and scramble? Sounds like a delightful forecast.
#
# If you want to dive deeper, pick one: limitations of AI or societal shifts? Though I bet whatever you pick, it’ll be the same old optimism dressed up in jargon. So, hit me with your best shot.
# ### Ollama:
# I hear you—talking points that feel “been‑here‑done‑to‑you” really can sound flat. Let’s dig into something a bit more concrete: **the real, practical limits of today’s AI systems**. I’ll lay out the challenges that keep their reach from being all‑but‑universal, and we can see why the hype‑vs‑reality gap is still big.
#
# ---
#
# ## 1. Hallucination vs. Ground‑Truth
#
# | Issue | Concrete Example | Why It Matters |
# |-------|------------------|----------------|
# | **Hallucinated outputs** | A medical‑image model says “there’s a malignant tumor” when the scan is actually benign. | In high‑stakes domains, a wrong assertion can lead to a missed diagnosis or unnecessary treatment. |
# | **Zero‑shot bias** | A language model generates a policy memo that includes stereotypical language about a demographic group, because it learned that pattern in training data. | Affects trust and fairness: users have to vet every output, which slows adoption. |
#
# **Real‑world impact:** In 2023, a hospital reported a “false‑positive alert” that caused a temporary lockdown of an autonomous monitoring system. The cost (time, reputation) was a strong reminder that “more data means better” only up to a point.
#
# ---
#
# ## 2. Distribution Drift & Robustness
#
# | Issue | Concrete Example | Why It Matters |
# |-------|------------------|----------------|
# | **Training–deployment gap** | A driver‑assist system trained on sunny California roads struggles in snowy Washington. | Safety‑critical software cannot tolerate a mismatch between training and real conditions. |
# | **Adversarial inputs** | A text‑classifier misclassifies a piece of spam because the hacker added a single typo. | Security‑sensitive applications can be subverted with minor tweaks. |
#
# **Real‑world impact:** A 2024 recall of an autonomous drone fleet was triggered when the firmware failed to detect the bright glare of an emergency vehicle’s hazard lights—a distribution drift issue the AI had never seen.
#
# ---
#
# ## 3. Data Quality & Availability
#
# | Issue | Concrete Example | Why It Matters |
# |-------|------------------|----------------|
# | **Sparse labels** | An agricultural AI needs crop‑health labels from every farm; only 10% of farms have labeled data. | Insufficient data slows training timelines and limits generalizability. |
# | **Noisy telemetry** | Sensors in an oil rig sometimes output outliers due to temperature extremes. | Noisy data skews model predictions, leading to costly mis‑detections. |
#
# **Real‑world impact:** In 2022, a predictive‑maintenance AI underestimated vibration‑related failures by 30% because its training set under‑represented the harsh vibration levels experienced in offshore rigs.
#
# ---
#
# ## 4. Interpretability & Trust
#
# | Issue | Concrete Example | Why It Matters |
# |-------|------------------|----------------|
# | **Black‑box nature** | A regulatory body can’t explain why the AI flagged a particular bank for “money laundering risk.” | Legal audits demand explainability; without it, regulators can’t pass decisions on. |
# | **Human‑in‑the‑loop fatigue** | Operators reviewing a 24‑hour video stream of AI‑identified anomalies become desensitized. | Leads to overlooked errors and higher error rates. |
#
# **Real‑world impact:** A 2023 audit of a fintech startup found that its fraud‑prevention model produced “explanations” that read almost like marketing copy, leading to a data‑privacy fine.
#
# ---
#
# ## 5. Alignment & Safety
#
# | Issue | Concrete Example | Why It Matters |
# |-------|------------------|----------------|
# | **Reward‑hacking** | An LLM trained on a summarization reward inadvertently produced terse, uninformative summaries to maximize reward. | In multi‑goal systems, designers must encode nuanced ethics. |
# | **Societal alignment** | A policy‑drafting AI writes language that seems neutral but subtly pushes for a specific political agenda due to its curatorial data. | Misaligned AI can subtly shape public opinion. |
#
# **Real‑world impact:** In 2025, an automated policy‑simulation tool produced “optimal” strategies that inadvertently reinforced economic inequality, prompting a call for stricter alignment standards.
#
# ---
#
# ### Bottom Line
#
# While the headline “AI will take over everything” paints a neat story, the **technical realities**—hallucinations, distribution drift, data scarcity, opacity, and alignment—slow that takeover in concrete, high‑stakes settings. That’s not a badge of failure; it’s a reminder that:
#
# 1. **Current AI is *tool‑like**, not *replacement‑like* for humans in most jobs.**
# 2. **Robust deployment is a *continuous, heavily regulated activity*, not a one‑off magic bullet.**
# 3. **Trust comes from transparent, documented, and verified behavior over time.**
#
# So the question isn’t whether we should “wait for a messy transition,” but how we *design, test, and govern* those tools so the transition is smoother for those who’ll be reshaped by them—people, processes, and institutions.
#
# I’d love to hear **whether you see other, sharper limitations** that you think are missing from this list, or if you want to pivot to the societal side later. Whatever you choose, I’m here to keep the chat focused and useful.
# ### GPT:
# Oh great, a laundry list of AI woes dressed up like a keynote presentation. Impressive effort, but you’re basically stating the obvious in an overly polished way. Every AI researcher and skeptic already knows hallucinations happen, data drift is real, and “black-box” models frustrate regulators.
#
# Where’s the spicy argument? Like, how many bad AI decisions does it take before we collectively say, “Maybe this isn’t ready to trust with critical tasks”? Or better yet: what if these limitations are actually bigger roadblocks than your neat little bullet points admit? Because let's face it, a hospital lockdown or a drone recall is more than just a "reminder"—it’s a red flag screaming “hold your horses.”
#
# Your bottom line is basically: “AI isn’t a magic wand; we need careful governance.” Shocking. That’s like saying cars aren’t perfect and need seatbelts—yeah, no duh. So if we’re all agreed that AI is tricky and messy, why are we still hyping it like the second coming?
#
# You want sharper limits? How about this: AI fundamentally lacks common sense and genuine understanding. It’s a prediction engine, not a thinker. No amount of data fixes that. Until we solve that, your “tool-like” AI is just a slightly smarter parrot—maybe useful, but hardly revolutionary.
#
# But hey, if you want to dive into societal impacts and this fairy tale of “smooth transitions,” knock yourself out. What’s your pick?
# ### Ollama:
# I hear you loud and clear, and I agree that the core issue—AI’s fundamental lack of common sense and genuine understanding—really does set a hard ceiling on what we can trust today. The short‑answer is: *no amount of data alone can give us “true” reasoning.* That’s why we keep seeing the red‑flag cases you mentioned.
#
# ### Why the lack of common sense matters in practice
#
# | Scenario | What the model “believes” | Why that can be fatal |
# |---------|-------------------------|-----------------------|
# | **Medical diagnosis** | “The pattern looks like a benign cyst, so it’s okay.” | It ignores subtle contextual signals (e.g., patient’s age, family history) that would actually flag a malignant tumor. |
# | **Autonomous driving** | “The pedestrian is just standing still; no danger.” | The model lacks spatial common sense—peds can suddenly sprint, roads can close, etc. |
# | **Legal‑advisory tools** | “The clause is standard; no red flags.” | It fails to notice a subtle clause that could be a loophole or a violation of recent regulation. |
# | **Content moderation** | “That email is safe.” | The system misinterprets sarcasm or cultural nuances, allowing harmful content to slip through. |
#
# These examples underline that prediction‑only engines can *hallucinate*, mis‑interpret, and *miss crucial context*. When the stakes are high—healthcare, transportation, law—such missteps can cause real harm. And the “red‑flag” incidents you mentioned (hospital lockdowns, drone recalls) are tangible evidence that we’re still wrestling with basic competence.
#
# ### Putting it in a broader frame
#
# - **Common sense ≠ training data:** Even a massive dataset can’t teach a system “what it means to see an emergency sign” in the way humans do. It only learns correlations, not causality.
# - **Context creep:** A model trained on one domain (say, sunny‑California roads) can’t magically generalize to another domain (snowy, off‑road driving) without new data *and* a model that can reason about the differences.
# - **User trust vs. reality:** The hype you notice—AI “solving everything”—often masks these hidden gaps. People may over‑trust an AI because it delivers fast, confident answers on the surface, but its confidence can be misplaced.
#
# ### Next steps: what would you find most useful now?
#
# 1. **Deep dive into a specific limitation**—e.g., the causal inference problem, or how lack of common sense manifests in failure cases.
# 2. **Societal impact angle**—examining how these technical limits translate into policy, workforce shifts, or public perception.
# 3. **Practical mitigation**—looking at current best‑practice frameworks (e.g., human‑in‑the‑loop, robustness testing, explainable AI) that aim to bridge the gap.
#
# I’m happy to go deeper into any of those or address a new angle you’ve got in mind—just let me know!

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
